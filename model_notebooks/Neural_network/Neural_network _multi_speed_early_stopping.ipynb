# %%
import numpy as np
import pandas as pd

# %%
turb_data=pd.read_csv('../../turb_data.csv')
turb_data
# Out:
#           x_coord  y_coord  ref_wind_speed  wind_speed  turb_num  \
# 0        0.000000      0.0        4.359392           6         0
# 1     2633.103635   -226.0        4.387136           6         1
# 2       57.854836   -545.0        4.358929           6         2
# 3        0.000000      0.0        4.355684           6         0
# 4     1935.499403    264.0        4.383674           6         1
# ...           ...      ...             ...         ...       ...
# 3835   294.588246    -52.0       18.847122          20         1
# 3836  1773.331277   -295.0       19.222500          20         2
# 3837     0.000000      0.0       19.118147          20         0
# 3838  3106.576695   -431.0       19.286488          20         1
# 3839   624.261321   -139.0       19.148735          20         2
#
#       num_tot_turb                          ID  IDnum
# 0                3  3_turbine_155th_simulation      0
# 1                3  3_turbine_155th_simulation      0
# 2                3  3_turbine_155th_simulation      0
# 3                3  3_turbine_141th_simulation      1
# 4                3  3_turbine_141th_simulation      1
# ...            ...                         ...    ...
# 3835             3   3_turbine_65th_simulation   1278
# 3836             3   3_turbine_65th_simulation   1278
# 3837             3   3_turbine_71th_simulation   1279
# 3838             3   3_turbine_71th_simulation   1279
# 3839             3   3_turbine_71th_simulation   1279
#
# [3840 rows x 8 columns]

# %%
dataset=turb_data.drop(['ID','turb_num'], axis=1)

# %%
import os
os.chdir("../..")
import descriptor.three_desc_model as desc
from descriptor.cutoffs import Polynomial
import matplotlib.pyplot as plt
import GPy
from IPython.display import display
symbol="Siemens"
turb = [symbol]
numsims=dataset["IDnum"].iloc[-1]+1

# %%
def build_and_compile_model(norm):
    model = keras.Sequential([
        norm,
        layers.Dense(64, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(16, activation='relu'),
        layers.Dense(1)
    ])
    model.compile(loss='mean_absolute_error', optimizer=tf.keras.optimizers.Adam(0.001))
    return model

# %%
# Gs = desc.make_symmetry_functions(turbines=symbol, type='G2',
#                                     etas=np.linspace(1,10,5),
#                                     offsets=[2])
# Gs += desc.make_symmetry_functions(turbines=symbol, type='G4',
#                                      etas=np.linspace(1,10,5),
#                                      gammas=[10])
# Gs += desc.make_symmetry_functions(turbines=symbol, type='G6',
#                                      etas=np.linspace(1,10,5),
#                                      gammas=[0])

# %%
# Gs = {"Siemens": [{"type":"G2", "turbine":"Siemens","eta":4.25387599, "offset": 1.0151402},
#                   {"type":"G4", "elements":"Siemens","eta":2.56450515, "gamma":8.04475192},
#                   {"type":"G6", "elements":"Siemens","eta":2.33043463, "gamma": 0.50753377}
#                  ]}

# %%
Gs = {"Siemens": [{"type":"G2", "turbine":"Siemens","eta":3.24310834, "offset": 1.9817547},
                  {"type":"G4", "elements":"Siemens","eta":2.48579287, "gamma":12.39114317},
                  {"type":"G6", "elements":"Siemens","eta":1.27537145, "gamma": 0.2110151}
                 ]}

# %%
nl=desc.NeighborlistCalculator(cutoff=4001,cone_grad=0.12582561117875557, cone_offset=72.24947126849844)
finpr=desc.FingerprintCalculator(cutoff=4001,Gs=Gs,Rct=3000,delta_R=100,cone_grad=0.12582561117875557, cone_offset=72.24947126849844)
count=0
dataset_fp=np.empty(shape=(0, 3))#len(Gs)))
dataset_rws=np.empty(shape=(0, 1))
dataset_ws=np.empty(shape=(0, 1))
dataset_pos=np.empty(shape=(0, 2))
for i in range(numsims):
    numturb=dataset["num_tot_turb"].iloc[count]
    position = np.empty((numturb,2))
    ws = np.empty((numturb,1))
    fp = np.empty((numturb,3))
    rws = np.empty((numturb,1))
    for k in range(numturb):
        position[k,0]=dataset["x_coord"].iloc[count]
        position[k,1]=dataset["y_coord"].iloc[count]
        ws[k,0]=dataset["wind_speed"].iloc[count]
        rws[k,0]=dataset["ref_wind_speed"].iloc[count]
        count = count+ 1
    neigh=nl.calculate(turb*numturb,position)
    fingerprints=finpr.calculate(turb*numturb,position,neigh,symbol)
    fingerprints=np.array(fingerprints)
    dataset_fp=np.append(dataset_fp,fingerprints,axis=0)
    dataset_rws=np.append(dataset_rws,rws,axis=0)
    dataset_ws=np.append(dataset_ws,ws,axis=0)
    dataset_pos=np.append(dataset_pos,position,axis=0)
dataset=np.concatenate((dataset_fp, dataset_ws, dataset_rws),axis=1)
dataset = pd.DataFrame(dataset)#, columns = ['Fingerprint(G2)','Fingerprint(G4)','Fingerprint(G6)','Ref_Wind_Speed','Wind_Speed'])

train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

train_features = train_dataset.copy()
test_features = test_dataset.copy()
all_features = dataset.copy()

train_labels = train_features.iloc[:,-1]
test_labels = test_features.iloc[:,-1]
all_labels = all_features.iloc[:,-1]

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import keras
from tensorflow.keras import layers, callbacks
from tensorflow.keras.layers.experimental import preprocessing
from sklearn.model_selection import train_test_split
normalizer = preprocessing.Normalization(axis=-1)
normalizer.adapt(np.array(train_features))
# Out:
# 2023-07-28 12:30:40.620410: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-28 12:30:49.421822: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def train_model(model, X_train, y_train, X_val, y_val, batch_size=32):
    early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10000, callbacks=[early_stopping], batch_size=batch_size)

    return history

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 5)                11
#  n)
#
#  dense (Dense)               (None, 64)                384
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 7,180
# Trainable params: 7,169
# Non-trainable params: 11
# _________________________________________________________________

# %%
X_train, X_val, y_train, y_val = train_test_split(train_features, train_labels, test_size=0.2, random_state=42)
history = train_model(dnn_model, X_train,y_train, X_val, y_val, batch_size=8)
# Out:
# Epoch 1/10000
# 308/308 [==============================] - 1s 2ms/step - loss: 2.7796 - val_loss: 0.7374
# Epoch 2/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.4407 - val_loss: 0.3594
# Epoch 3/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.2456 - val_loss: 0.1981
# Epoch 4/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.1763 - val_loss: 0.2205
# Epoch 5/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.1344 - val_loss: 0.1419
# Epoch 6/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.1204 - val_loss: 0.1055
# Epoch 7/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.1167 - val_loss: 0.1008
# Epoch 8/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.1006 - val_loss: 0.1379
# Epoch 9/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0826 - val_loss: 0.1098
# Epoch 10/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.1028 - val_loss: 0.1869
# Epoch 11/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0867 - val_loss: 0.0675
# Epoch 12/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0856 - val_loss: 0.1414
# Epoch 13/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0898 - val_loss: 0.1084
# Epoch 14/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0808 - val_loss: 0.1753
# Epoch 15/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0739 - val_loss: 0.0690
# Epoch 16/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0664 - val_loss: 0.0761
# Epoch 17/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0727 - val_loss: 0.0487
# Epoch 18/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0835 - val_loss: 0.0853
# Epoch 19/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0748 - val_loss: 0.0547
# Epoch 20/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0655 - val_loss: 0.0657
# Epoch 21/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0760 - val_loss: 0.0986
# Epoch 22/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0856 - val_loss: 0.0265
# Epoch 23/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0682 - val_loss: 0.0650
# Epoch 24/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0679 - val_loss: 0.0624
# Epoch 25/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0611 - val_loss: 0.0520
# Epoch 26/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0641 - val_loss: 0.0566
# Epoch 27/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0619 - val_loss: 0.0729
# Epoch 28/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0601 - val_loss: 0.0474
# Epoch 29/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0646 - val_loss: 0.0577
# Epoch 30/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0591 - val_loss: 0.0489
# Epoch 31/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0588 - val_loss: 0.0411
# Epoch 32/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0675 - val_loss: 0.0814
# Epoch 33/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0527 - val_loss: 0.0343
# Epoch 34/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0612 - val_loss: 0.0346
# Epoch 35/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0450 - val_loss: 0.0541
# Epoch 36/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0589 - val_loss: 0.0483
# Epoch 37/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0603 - val_loss: 0.1154
# Epoch 38/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0645 - val_loss: 0.0518
# Epoch 39/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0519 - val_loss: 0.0632
# Epoch 40/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0635 - val_loss: 0.0295
# Epoch 41/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0585 - val_loss: 0.0451
# Epoch 42/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0518 - val_loss: 0.0495
# Epoch 43/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0617 - val_loss: 0.0665
# Epoch 44/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0551 - val_loss: 0.0365
# Epoch 45/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0507 - val_loss: 0.0566
# Epoch 46/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0613 - val_loss: 0.0552
# Epoch 47/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0554 - val_loss: 0.0681
# Epoch 48/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0523 - val_loss: 0.0609
# Epoch 49/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0538 - val_loss: 0.1156
# Epoch 50/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0564 - val_loss: 0.0719
# Epoch 51/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0564 - val_loss: 0.0564
# Epoch 52/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0564 - val_loss: 0.0349
# Epoch 53/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0527 - val_loss: 0.0928
# Epoch 54/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0546 - val_loss: 0.0379
# Epoch 55/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0482 - val_loss: 0.1571
# Epoch 56/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0556 - val_loss: 0.0973
# Epoch 57/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0543 - val_loss: 0.0388
# Epoch 58/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0597 - val_loss: 0.0282
# Epoch 59/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0521 - val_loss: 0.0725
# Epoch 60/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0529 - val_loss: 0.0621
# Epoch 61/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0500 - val_loss: 0.0374
# Epoch 62/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0384 - val_loss: 0.0321
# Epoch 63/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0491 - val_loss: 0.0570
# Epoch 64/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0497 - val_loss: 0.0929
# Epoch 65/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0437 - val_loss: 0.0778
# Epoch 66/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0448 - val_loss: 0.0758
# Epoch 67/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0482 - val_loss: 0.0346
# Epoch 68/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0505 - val_loss: 0.0333
# Epoch 69/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0479 - val_loss: 0.0362
# Epoch 70/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0533 - val_loss: 0.0514
# Epoch 71/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0403 - val_loss: 0.0384
# Epoch 72/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0567
# Epoch 73/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0564 - val_loss: 0.0778
# Epoch 74/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0335
# Epoch 75/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0550 - val_loss: 0.0755
# Epoch 76/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0406 - val_loss: 0.0352
# Epoch 77/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0479 - val_loss: 0.0214
# Epoch 78/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0471 - val_loss: 0.0186
# Epoch 79/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0441 - val_loss: 0.0671
# Epoch 80/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0436 - val_loss: 0.0405
# Epoch 81/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0415 - val_loss: 0.1280
# Epoch 82/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0394
# Epoch 83/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0388 - val_loss: 0.0318
# Epoch 84/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0382 - val_loss: 0.0207
# Epoch 85/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0453 - val_loss: 0.0304
# Epoch 86/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0619 - val_loss: 0.0726
# Epoch 87/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0490 - val_loss: 0.0318
# Epoch 88/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0411 - val_loss: 0.0227
# Epoch 89/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0451 - val_loss: 0.0385
# Epoch 90/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0426 - val_loss: 0.0271
# Epoch 91/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0342 - val_loss: 0.0254
# Epoch 92/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0362 - val_loss: 0.0210
# Epoch 93/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0442 - val_loss: 0.0395
# Epoch 94/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0333 - val_loss: 0.0299
# Epoch 95/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0392 - val_loss: 0.0500
# Epoch 96/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0400 - val_loss: 0.0523
# Epoch 97/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0443 - val_loss: 0.0716
# Epoch 98/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0408 - val_loss: 0.0556
# Epoch 99/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0478 - val_loss: 0.0539
# Epoch 100/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0444 - val_loss: 0.1096
# Epoch 101/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0455 - val_loss: 0.0542
# Epoch 102/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0424 - val_loss: 0.0321
# Epoch 103/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0497 - val_loss: 0.0405
# Epoch 104/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0415 - val_loss: 0.0855
# Epoch 105/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0417 - val_loss: 0.0326
# Epoch 106/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0514 - val_loss: 0.0571
# Epoch 107/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0514 - val_loss: 0.0674
# Epoch 108/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0464
# Epoch 109/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0383 - val_loss: 0.0667
# Epoch 110/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0471 - val_loss: 0.0740
# Epoch 111/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0481 - val_loss: 0.0420
# Epoch 112/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0496 - val_loss: 0.0321
# Epoch 113/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0379 - val_loss: 0.0771
# Epoch 114/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0347 - val_loss: 0.1219
# Epoch 115/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0433 - val_loss: 0.0464
# Epoch 116/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0486 - val_loss: 0.0952
# Epoch 117/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0484 - val_loss: 0.0422
# Epoch 118/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0350 - val_loss: 0.0229
# Epoch 119/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0356 - val_loss: 0.0525
# Epoch 120/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0417 - val_loss: 0.0150
# Epoch 121/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0371 - val_loss: 0.0319
# Epoch 122/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0379 - val_loss: 0.0337
# Epoch 123/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0455 - val_loss: 0.0434
# Epoch 124/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0442 - val_loss: 0.0377
# Epoch 125/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0432 - val_loss: 0.0197
# Epoch 126/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0340 - val_loss: 0.0648
# Epoch 127/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0521 - val_loss: 0.0214
# Epoch 128/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0389 - val_loss: 0.0477
# Epoch 129/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0402 - val_loss: 0.0335
# Epoch 130/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0354 - val_loss: 0.1040
# Epoch 131/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0572 - val_loss: 0.1111
# Epoch 132/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0368 - val_loss: 0.0241
# Epoch 133/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0376 - val_loss: 0.0387
# Epoch 134/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0414 - val_loss: 0.0580
# Epoch 135/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0385 - val_loss: 0.1251
# Epoch 136/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0512 - val_loss: 0.0516
# Epoch 137/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0373 - val_loss: 0.1133
# Epoch 138/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0496 - val_loss: 0.0260
# Epoch 139/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0414 - val_loss: 0.0308
# Epoch 140/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0317 - val_loss: 0.0387
# Epoch 141/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0339 - val_loss: 0.0483
# Epoch 142/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0448 - val_loss: 0.0313
# Epoch 143/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0334 - val_loss: 0.0474
# Epoch 144/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0445 - val_loss: 0.0546
# Epoch 145/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0361 - val_loss: 0.0209
# Epoch 146/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0349 - val_loss: 0.0210
# Epoch 147/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0363 - val_loss: 0.0722
# Epoch 148/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0405 - val_loss: 0.0150
# Epoch 149/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0314 - val_loss: 0.0512
# Epoch 150/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0486 - val_loss: 0.0266
# Epoch 151/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0327 - val_loss: 0.0208
# Epoch 152/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0400 - val_loss: 0.0381
# Epoch 153/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0307 - val_loss: 0.0077
# Epoch 154/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0406 - val_loss: 0.0271
# Epoch 155/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0354 - val_loss: 0.0618
# Epoch 156/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0440 - val_loss: 0.0373
# Epoch 157/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0308 - val_loss: 0.0316
# Epoch 158/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0441 - val_loss: 0.0506
# Epoch 159/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0334 - val_loss: 0.0683
# Epoch 160/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0405 - val_loss: 0.0430
# Epoch 161/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0308 - val_loss: 0.0564
# Epoch 162/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0346 - val_loss: 0.0239
# Epoch 163/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0411 - val_loss: 0.0358
# Epoch 164/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0417 - val_loss: 0.1110
# Epoch 165/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0425 - val_loss: 0.0391
# Epoch 166/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0419 - val_loss: 0.0812
# Epoch 167/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0356 - val_loss: 0.0179
# Epoch 168/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0375 - val_loss: 0.0798
# Epoch 169/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0387 - val_loss: 0.0285
# Epoch 170/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0386 - val_loss: 0.0401
# Epoch 171/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0414 - val_loss: 0.0253
# Epoch 172/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0313 - val_loss: 0.0183
# Epoch 173/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0377
# Epoch 174/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0356 - val_loss: 0.0304
# Epoch 175/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0321 - val_loss: 0.0798
# Epoch 176/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0354 - val_loss: 0.0665
# Epoch 177/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0400 - val_loss: 0.0418
# Epoch 178/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0393 - val_loss: 0.0157
# Epoch 179/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0313 - val_loss: 0.0236
# Epoch 180/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0375 - val_loss: 0.0564
# Epoch 181/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0456 - val_loss: 0.0477
# Epoch 182/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0357 - val_loss: 0.0681
# Epoch 183/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0339 - val_loss: 0.0180
# Epoch 184/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0417 - val_loss: 0.0432
# Epoch 185/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0376 - val_loss: 0.0245
# Epoch 186/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0341 - val_loss: 0.0792
# Epoch 187/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0315 - val_loss: 0.0248
# Epoch 188/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0319 - val_loss: 0.0626
# Epoch 189/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0417 - val_loss: 0.0207
# Epoch 190/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0350 - val_loss: 0.0343
# Epoch 191/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0329 - val_loss: 0.0260
# Epoch 192/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0323 - val_loss: 0.0247
# Epoch 193/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0314 - val_loss: 0.0854
# Epoch 194/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0234
# Epoch 195/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0296 - val_loss: 0.0662
# Epoch 196/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0456 - val_loss: 0.0350
# Epoch 197/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0455 - val_loss: 0.0454
# Epoch 198/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0330 - val_loss: 0.0201
# Epoch 199/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0416 - val_loss: 0.0515
# Epoch 200/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0414 - val_loss: 0.0512
# Epoch 201/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0381 - val_loss: 0.0323
# Epoch 202/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0379 - val_loss: 0.0298
# Epoch 203/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0277 - val_loss: 0.0280
# Epoch 204/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0351 - val_loss: 0.0652
# Epoch 205/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0310 - val_loss: 0.0203
# Epoch 206/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0314 - val_loss: 0.0144
# Epoch 207/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0345 - val_loss: 0.0247
# Epoch 208/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0343 - val_loss: 0.0818
# Epoch 209/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0350 - val_loss: 0.0291
# Epoch 210/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0251 - val_loss: 0.0213
# Epoch 211/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0281 - val_loss: 0.0137
# Epoch 212/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0280 - val_loss: 0.0164
# Epoch 213/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0361 - val_loss: 0.0144
# Epoch 214/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0318 - val_loss: 0.0511
# Epoch 215/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0347 - val_loss: 0.0302
# Epoch 216/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0286 - val_loss: 0.0854
# Epoch 217/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0371 - val_loss: 0.0741
# Epoch 218/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0364 - val_loss: 0.0663
# Epoch 219/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0310 - val_loss: 0.0128
# Epoch 220/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0350 - val_loss: 0.0398
# Epoch 221/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0364 - val_loss: 0.0464
# Epoch 222/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0373 - val_loss: 0.0373
# Epoch 223/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0283 - val_loss: 0.0629
# Epoch 224/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0301 - val_loss: 0.0192
# Epoch 225/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0295 - val_loss: 0.0251
# Epoch 226/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0390 - val_loss: 0.0182
# Epoch 227/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0363 - val_loss: 0.0132
# Epoch 228/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0269 - val_loss: 0.0160
# Epoch 229/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0335 - val_loss: 0.0690
# Epoch 230/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0294 - val_loss: 0.0248
# Epoch 231/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0296 - val_loss: 0.0411
# Epoch 232/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0333 - val_loss: 0.0315
# Epoch 233/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0403 - val_loss: 0.0133
# Epoch 234/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 0.0274
# Epoch 235/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0335 - val_loss: 0.0251
# Epoch 236/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0295 - val_loss: 0.0322
# Epoch 237/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0343 - val_loss: 0.0177
# Epoch 238/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0387 - val_loss: 0.0187
# Epoch 239/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0275 - val_loss: 0.0254
# Epoch 240/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0293 - val_loss: 0.0545
# Epoch 241/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0290 - val_loss: 0.0236
# Epoch 242/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0375 - val_loss: 0.0102
# Epoch 243/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0301 - val_loss: 0.0104
# Epoch 244/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0318 - val_loss: 0.0522
# Epoch 245/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0316 - val_loss: 0.0309
# Epoch 246/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0287 - val_loss: 0.0394
# Epoch 247/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0354 - val_loss: 0.0593
# Epoch 248/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0315 - val_loss: 0.0371
# Epoch 249/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0295 - val_loss: 0.0205
# Epoch 250/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0307 - val_loss: 0.0244
# Epoch 251/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0243 - val_loss: 0.0287
# Epoch 252/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0309 - val_loss: 0.0171
# Epoch 253/10000
# 308/308 [==============================] - 0s 1ms/step - loss: 0.0301 - val_loss: 0.0162

# %%
# %%time
# history = dnn_model.fit(
#     train_features, train_labels,
#     validation_split=0.2,
#     verbose=0, epochs=10000)

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='train_error', color='C0')
    plt.plot(history.history['val_loss'], label='validation_error', color='C1')
    plt.ylim([0, 0.25])
    plt.xlabel('Epoch')
    plt.ylabel('Absolute Error [m/s]')
    plt.legend()
    plt.grid(True)

# %%
plot_loss(history)

# %%
test_predictions = dnn_model.predict(test_features).flatten()
train_predictions = dnn_model.predict(train_features).flatten()
all_predictions = dnn_model.predict(all_features).flatten()
#test_predictions_0 = dnn_model.predict(test_features["Fingerprint(G2)"]==0).flatten()
#train_predictions_0 = dnn_model.predict(train_features["Fingerprint(G2)"]==0).flatten()
plt.figure(dpi=1200)
a = plt.axes(aspect='equal')
#plt.scatter(test_labels, test_predictions)#,c=test_features["Fingerprint(G2)"])
#plt.scatter(train_labels, train_predictions)#,c=train_features["Fingerprint(G2)"])
plt.scatter(all_labels, all_predictions)
plt.xlabel('True Values [Ref_wind_speed]')
plt.ylabel('Predictions [Ref_wind_speed]')
#cbar=plt.colorbar()
#cbar.set_label('Fingerprint(G2)')
lims = [2, 20]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# 24/24 [==============================] - 0s 818us/step
# 96/96 [==============================] - 0s 699us/step
# 120/120 [==============================] - 0s 1ms/step

# %%
plt.figure(dpi=1200)
a = plt.axes(aspect='equal')
#plt.scatter(test_labels, test_predictions)#,c=test_features["Fingerprint(G2)"])
#plt.scatter(train_labels, train_predictions)#,c=train_features["Fingerprint(G2)"])
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Ref_wind_speed]')
plt.ylabel('Predictions [Ref_wind_speed]')
plt.title('Test (unseen) data')
#cbar=plt.colorbar()
#cbar.set_label('Fingerprint(G2)')
lims = [2, 20]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
all_predictions = dnn_model.predict(all_features).flatten()
a = plt.axes
error_all=np.abs(all_predictions-all_labels)

plt.scatter(dataset_pos[:,0], dataset_pos[:,1],c=error_all)
#plt.scatter(train_features["Fingerprint(G2)"], train_features["Fingerprint(G4)"],c=train_labels)
#plt.scatter(train_labels, train_predictions)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Error Rate Locations')
cbar=plt.colorbar()
cbar.set_label('Absolute Error Rate (m/s)')
# Out:
# 120/120 [==============================] - 0s 720us/step

# %%
arg=np.argsort(error_all)
error_all[arg]
# Out:
# 1057    0.000002
# 1048    0.000005
# 1024    0.000005
# 1499    0.000006
# 701     0.000006
#           ...
# 274     0.121146
# 43      0.122984
# 550     0.156129
# 221     0.236472
# 146     0.280551
# Name: 4, Length: 3840, dtype: float64

# %%
all_predictions = dnn_model.predict(all_features).flatten()
a = plt.axes
error_all=np.abs(all_predictions-all_labels)

plt.scatter(dataset_pos[arg[-20:],0], dataset_pos[arg[-20:],1],c=error_all[arg[-20:]])
#plt.scatter(train_features["Fingerprint(G2)"], train_features["Fingerprint(G4)"],c=train_labels)
#plt.scatter(train_labels, train_predictions)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.colorbar()
# Out:
# 120/120 [==============================] - 0s 687us/step

# %%
error_test = np.abs(test_predictions - test_labels)
plt.hist(error_test, bins=10)
plt.xlabel('Test Error [Ref_wind_speed]')
_ = plt.ylabel('Count')

# %%
error_train = np.abs(train_predictions - train_labels)
plt.hist(error_train, bins=10)
plt.xlabel('Train Error [Ref_wind_speed]')
_ = plt.ylabel('Count')

# %%
print("Max test error:",np.max(error_test))
print("Mean test error:",np.mean(error_test))
# Out:
# Max test error: 0.28055119218627933
# Mean test error: 0.00872638024248993

# %%
print("Max all error:",np.max(error_all))
print("Mean all error:",np.mean(error_all))
# Out:
# Max all error: 0.28055119218627933
# Mean all error: 0.008070872453663669

# %%
print("Max train error:",np.max(error_train))
print("Mean train error:",np.mean(error_train))
# Out:
# Max train error: 0.12298369196472159
# Mean train error: 0.007906998843696328

# %%
dnn_model.save('dnn_model')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: dnn_model/assets
# INFO:tensorflow:Assets written to: dnn_model/assets

# %%
print(min(error),max(error))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pt/6w8cqgmd4vq_01nqjykyvkpw0000gn/T/ipykernel_69044/2994616141.py in <module>
# ----> 1 print(min(error),max(error))
#
# NameError: name 'error' is not defined

# %%
import matplotlib.cm as cm
plt.scatter(dataset['Fingerprint(G4)'],dataset['Fingerprint(G2)'], c=dataset['Ref_Wind_Speed'], s=10, cmap=cm.bwr)
cbar= plt.colorbar()
plt.xlabel('Fingerprint(G4)')
plt.ylabel('Fingerprint(G2)')
plt.show()

# %%
# dnn_model.evaluate(test_features, test_labels, verbose=0)

# %%
# import numpy
# from mayavi.mlab import *

# def test_points3d():


#     x = all_features["Fingerprint(G2)"]
#     y = all_features["Fingerprint(G4)"]
#     z = all_features["Fingerprint(G6)"]
#     s = error_all
#     colorbar(orientation='vertical')
#     xlabel('Fingerprint(G2)')
#     ylabel('Fingerprint(G4)')
#     zlabel('Fingerprint(G6)')
#     return points3d(x, y, z, s, colormap="blue-red", scale_factor=0.05)
# test_points3d()
# #colorbar(object=all_labels, title="Points in Mayavi")
# #view()
# show()
